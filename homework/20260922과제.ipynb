# %% [markdown]
# ## 결측치 처리

# %%
import pandas as pd 
url = 'https://raw.githubusercontent.com/sehakflower/data/main/titanic.csv'
titanic_df = pd.read_csv(url, sep='\t')
titanic_df.columns = titanic_df.columns.str.lower()
titanic_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   passengerid  156 non-null    int64
#  1   survived     156 non-null    int64
#  2   pclass       156 non-null    int64
#  3   name         156 non-null    str
#  4   sex          156 non-null    str
#  5   age          126 non-null    float64
#  6   sibsp        156 non-null    int64
#  7   parch        156 non-null    int64
#  8   ticket       156 non-null    str
#  9   fare         156 non-null    float64
#  10  cabin        31 non-null     str
#  11  embarked     155 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 14.8 KB

# %%
titanic_df
# Out:
#      passengerid  survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 152                                   Meo, Mr. Alfonzo    male  55.5      0
# 153                    van Billiard, Mr. Austin Blyler    male  40.5      0
# 154                              Olsen, Mr. Ole Martin    male   NaN      0
# 155                        Williams, Mr. Charles Duane    male  51.0      0
#
#      parch            ticket     fare cabin embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 151      0            113776  66.6000    C2        S
# 152      0        A.5. 11206   8.0500   NaN        S
# 153      2          A/5. 851  14.5000   NaN        S
# 154      0         Fa 265302   7.3125   NaN        S
# 155      1          PC 17597  61.3792   NaN        C
#
# [156 rows x 12 columns]

# %%
new_columns=['passengerId', 'survived', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket', 'fare', 'cabin', 'embarked']
titanic_df.columns = new_columns
titanic_df.columns
# Out:
# Index(['passengerId', 'survived', 'pclass', 'name', 'sex', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked'],
#       dtype='str')

# %%
titanic_df['age'][titanic_df['age'].isna()]
# Out:
# 5     NaN
# 17    NaN
# 19    NaN
# 26    NaN
# 28    NaN
# 29    NaN
# 31    NaN
# 32    NaN
# 36    NaN
# 42    NaN
# 45    NaN
# 46    NaN
# 47    NaN
# 48    NaN
# 55    NaN
# 64    NaN
# 65    NaN
# 76    NaN
# 77    NaN
# 82    NaN
# 87    NaN
# 95    NaN
# 101   NaN
# 107   NaN
# 109   NaN
# 121   NaN
# 126   NaN
# 128   NaN
# 140   NaN
# 154   NaN
# Name: age, dtype: float64

# %%
titanic_df['age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154     True
# 155    False
# Name: age, Length: 156, dtype: bool

# %%
titanic_df['age'][titanic_df['age'].isnull()]
# Out:
# 5     NaN
# 17    NaN
# 19    NaN
# 26    NaN
# 28    NaN
# 29    NaN
# 31    NaN
# 32    NaN
# 36    NaN
# 42    NaN
# 45    NaN
# 46    NaN
# 47    NaN
# 48    NaN
# 55    NaN
# 64    NaN
# 65    NaN
# 76    NaN
# 77    NaN
# 82    NaN
# 87    NaN
# 95    NaN
# 101   NaN
# 107   NaN
# 109   NaN
# 121   NaN
# 126   NaN
# 128   NaN
# 140   NaN
# 154   NaN
# Name: age, dtype: float64

# %%
titanic_df['age'][titanic_df['age'].isnull()].isnull().sum()
# Out:
# np.int64(30)

# %%
titanic_df['age'].notnull()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 151     True
# 152     True
# 153     True
# 154    False
# 155     True
# Name: age, Length: 156, dtype: bool

# %%
titanic_df['age'][titanic_df['age'].notnull()]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 150    51.0
# 151    22.0
# 152    55.5
# 153    40.5
# 155    51.0
# Name: age, Length: 126, dtype: float64

# %%
titanic_df.loc[titanic_df['age'].notnull(),['age', 'name']]
# Out:
#       age                                               name
# 0    22.0                            Braund, Mr. Owen Harris
# 1    38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2    26.0                             Heikkinen, Miss. Laina
# 3    35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4    35.0                           Allen, Mr. William Henry
# ..    ...                                                ...
# 150  51.0                         Bateman, Rev. Robert James
# 151  22.0                  Pears, Mrs. Thomas (Edith Wearne)
# 152  55.5                                   Meo, Mr. Alfonzo
# 153  40.5                    van Billiard, Mr. Austin Blyler
# 155  51.0                        Williams, Mr. Charles Duane
#
# [126 rows x 2 columns]

# %%
titanic_df.head()
# Out:
#    passengerId  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df['cabin']=titanic_df['cabin'].fillna('N')
titanic_df['cabin']
# Out:
# 0         N
# 1       C85
# 2         N
# 3      C123
# 4         N
#        ...
# 151      C2
# 152       N
# 153       N
# 154       N
# 155       N
# Name: cabin, Length: 156, dtype: str

# %%
titanic_df['cabin'].value_counts()
# Out:
# cabin
# N              125
# C123             2
# C23 C25 C27      2
# D26              2
# C85              1
# E46              1
# G6               1
# C103             1
# D56              1
# A6               1
# B78              1
# D33              1
# B30              1
# C52              1
# B28              1
# C83              1
# F33              1
# F G73            1
# E31              1
# A5               1
# D10 D12          1
# C110             1
# B58 B60          1
# E101             1
# F E69            1
# D47              1
# B86              1
# F2               1
# C2               1
# Name: count, dtype: int64

# %%
titanic_df['cabin'][0]
# Out:
# 'N'

# %%
titanic_df['cabin']=titanic_df['cabin'].apply(lambda x : x[0])
titanic_df['cabin']
# Out:
# 0      N
# 1      C
# 2      N
# 3      C
# 4      N
#       ..
# 151    C
# 152    N
# 153    N
# 154    N
# 155    N
# Name: cabin, Length: 156, dtype: str

# %%
titanic_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   passengerId  156 non-null    int64
#  1   survived     156 non-null    int64
#  2   pclass       156 non-null    int64
#  3   name         156 non-null    str
#  4   sex          156 non-null    str
#  5   age          126 non-null    float64
#  6   sibsp        156 non-null    int64
#  7   parch        156 non-null    int64
#  8   ticket       156 non-null    str
#  9   fare         156 non-null    float64
#  10  cabin        156 non-null    str
#  11  embarked     155 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 14.8 KB

# %%
titanic_df_copy = titanic_df.copy()
titanic_df_copy
# Out:
#      passengerId  survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 152                                   Meo, Mr. Alfonzo    male  55.5      0
# 153                    van Billiard, Mr. Austin Blyler    male  40.5      0
# 154                              Olsen, Mr. Ole Martin    male   NaN      0
# 155                        Williams, Mr. Charles Duane    male  51.0      0
#
#      parch            ticket     fare cabin embarked
# 0        0         A/5 21171   7.2500     N        S
# 1        0          PC 17599  71.2833     C        C
# 2        0  STON/O2. 3101282   7.9250     N        S
# 3        0            113803  53.1000     C        S
# 4        0            373450   8.0500     N        S
# ..     ...               ...      ...   ...      ...
# 151      0            113776  66.6000     C        S
# 152      0        A.5. 11206   8.0500     N        S
# 153      2          A/5. 851  14.5000     N        S
# 154      0         Fa 265302   7.3125     N        S
# 155      1          PC 17597  61.3792     N        C
#
# [156 rows x 12 columns]

# %%
titanic_df_copy['age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154     True
# 155    False
# Name: age, Length: 156, dtype: bool

# %%
titanic_df_copy['age']=titanic_df_copy['age'].fillna(titanic_df_copy['age'].mean())
titanic_df_copy['age']
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 151    22.000000
# 152    55.500000
# 153    40.500000
# 154    28.141508
# 155    51.000000
# Name: age, Length: 156, dtype: float64

# %%
copy_titanic_df=titanic_df.copy()
copy_titanic_df
# Out:
#      passengerId  survived  pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   name     sex   age  sibsp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 152                                   Meo, Mr. Alfonzo    male  55.5      0
# 153                    van Billiard, Mr. Austin Blyler    male  40.5      0
# 154                              Olsen, Mr. Ole Martin    male   NaN      0
# 155                        Williams, Mr. Charles Duane    male  51.0      0
#
#      parch            ticket     fare cabin embarked
# 0        0         A/5 21171   7.2500     N        S
# 1        0          PC 17599  71.2833     C        C
# 2        0  STON/O2. 3101282   7.9250     N        S
# 3        0            113803  53.1000     C        S
# 4        0            373450   8.0500     N        S
# ..     ...               ...      ...   ...      ...
# 151      0            113776  66.6000     C        S
# 152      0        A.5. 11206   8.0500     N        S
# 153      2          A/5. 851  14.5000     N        S
# 154      0         Fa 265302   7.3125     N        S
# 155      1          PC 17597  61.3792     N        C
#
# [156 rows x 12 columns]

# %%
hex(id(titanic_df))
# Out:
# '0x2de22769480'

# %%
hex(id(copy_titanic_df))
# Out:
# '0x2de22769bf0'

# %%
titanic_df.head()
# Out:
#    passengerId  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500     N        S
# 1      0          PC 17599  71.2833     C        C
# 2      0  STON/O2. 3101282   7.9250     N        S
# 3      0            113803  53.1000     C        S
# 4      0            373450   8.0500     N        S

# %%
copy_titanic_df.head()
# Out:
#    passengerId  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500     N        S
# 1      0          PC 17599  71.2833     C        C
# 2      0  STON/O2. 3101282   7.9250     N        S
# 3      0            113803  53.1000     C        S
# 4      0            373450   8.0500     N        S

# %%
copy_titanic_df['age']=0
copy_titanic_df.head()
# Out:
#    passengerId  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex  age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male    0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female    0      1
# 2                             Heikkinen, Miss. Laina  female    0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    0      1
# 4                           Allen, Mr. William Henry    male    0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500     N        S
# 1      0          PC 17599  71.2833     C        C
# 2      0  STON/O2. 3101282   7.9250     N        S
# 3      0            113803  53.1000     C        S
# 4      0            373450   8.0500     N        S

# %%
titanic_df.head()
# Out:
#    passengerId  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500     N        S
# 1      0          PC 17599  71.2833     C        C
# 2      0  STON/O2. 3101282   7.9250     N        S
# 3      0            113803  53.1000     C        S
# 4      0            373450   8.0500     N        S

# %% [markdown]
# ## 판다스의 통계 함수

# %%
titanic_df.describe()
# Out:
#        passengerId    survived      pclass         age       sibsp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             parch        fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
titanic_df.sum()
# Out:
# passengerId    672.177428
# survived       158.823429
# pclass         171.218535
# age            320.585388
# sibsp          163.671620
# parch          162.267582
# fare           546.089834
# dtype: float64

# %%
titanic_df.count()
# Out:
# passengerId    8
# survived       8
# pclass         8
# age            8
# sibsp          8
# parch          8
# fare           8
# dtype: int64

# %%
titanic_df.max()
# Out:
# passengerId    156.0
# survived       156.0
# pclass         156.0
# age            126.0
# sibsp          156.0
# parch          156.0
# fare           263.0
# dtype: float64

# %%
titanic_df.min()
# Out:
# passengerId    1.000000
# survived       0.000000
# pclass         0.795459
# age            0.830000
# sibsp          0.000000
# parch          0.000000
# fare           6.750000
# dtype: float64

# %%
titanic_df.mean(numeric_only=True)
# Out:
# passengerId    84.022178
# survived       19.852929
# pclass         21.402317
# age            40.073173
# sibsp          20.458952
# parch          20.283448
# fare           68.261229
# dtype: float64

# %%
titanic_df.median(numeric_only=True)
# Out:
# passengerId    78.500000
# survived        0.411714
# pclass          2.711538
# age            27.070754
# sibsp           0.807692
# parch           0.198718
# fare           29.240719
# dtype: float64

# %%
titanic_df.mode()
# Out:
#    passengerId  survived  pclass         age  sibsp  parch        fare
# 0         78.5       0.0     3.0    0.830000    0.0    0.0    6.750000
# 1        156.0       NaN     NaN   14.613880    NaN    NaN    8.003150
# 2          NaN       NaN     NaN   19.000000    NaN    NaN   14.454200
# 3          NaN       NaN     NaN   26.000000    NaN    NaN   28.109587
# 4          NaN       NaN     NaN   28.141508    NaN    NaN   30.371850
# 5          NaN       NaN     NaN   35.000000    NaN    NaN   39.401047
# 6          NaN       NaN     NaN   71.000000    NaN    NaN  156.000000
# 7          NaN       NaN     NaN  126.000000    NaN    NaN  263.000000

# %%
titanic_df.mad()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 titanic_df.mad()
#
# File ~\anaconda3\envs\pydate26\Lib\site-packages\pandas\core\generic.py:6194, in NDFrame.__getattr__(self, name)
#    6190             and name not in self._accessors
#    6191             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6192         ):
#    6193             return self[name]
# -> 6194         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'mad'

# %%
titanic_df.var(numeric_only=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 titanic_df.var()
#
# File ~\anaconda3\envs\pydate26\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\pydate26\Lib\site-packages\pandas\core\frame.py:14835, in DataFrame.var(self, axis, skipna, ddof, numeric_only, **kwargs)
#   14831         age       264.687500
#   14832         height      0.042275
#   14833         dtype: float64
#   14834         """
# > 14835         result = super().var(
#   14836             axis=axis, skipna=skipna, ddof=ddof, numeric_only=numeric_only, **kwargs
#   14837         )
#   14838         if isinstance(result, Series):
#
# File ~\anaconda3\envs\pydate26\Lib\site-packages\pandas\core\generic.py:11741, in NDFrame.var(self, axis, skipna, ddof, numeric_only, **kwargs)
#   11737         ddof: int = 1,
#   11738         numeric_only: bool = False,
#   11739         **kwargs,
#   11740     ) -> Series | float:
# > 11741         return self._stat_function_ddof(
#   11742             "var", nanops.nanvar, axis, skipna, ddof, numeric_only, **kwargs
#   11743         )
#
# File ~\anaconda3\envs\pydate26\Lib\site-packages\pandas\core\generic.py:11715, in NDFrame._stat_function_ddof(self, name, func, axis, skipna, ddof, numeric_only, **kwargs)
#   11711     ) -> Series | float:
#   11712         nv.validate_stat_ddof_func((), kwargs, fname=name)
#   11713         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   11714
# > 11715         return self._reduce(
#   11716             func, name, axis=axis, numeric_only=numeric_only, skipna=skipna, ddof=ddof
#   11717         )
#
# File ~\anaconda3\envs\pydate26\Lib\site-packages\pandas\core\frame.py:13635, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   13631             df = df.T
#   13632
#   13633         # After possibly _get_data and transposing, we are now in the
#   13634         #  simple case where we can use BlockManager.reduce
# > 13635         res = df._mgr.reduce(blk_func)
#   13636         out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   13637         out.name = None
#   13638         if out_dtype is not None and out.dtype != "boolean":
#
# File ~\anaconda3\envs\pydate26\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.reduce(self, func)
#    1691 # If 2D, we assume that we're operating column-wise
#    1692 assert self.ndim == 2
# -> 1694 res_blocks = [blk.reduce(func) for blk in self.blocks]
#    1695 index = default_index(1)  # placeholder
#    1696 # shallow copy self.items not needed because DataFrame._reduce does a getitem
#
# File ~\anaconda3\envs\pydate26\Lib\site-packages\pandas\core\internals\blocks.py:358, in Block.reduce(self, func)
#     352 @final
#     353 def reduce(self, func) -> Block:
#     354     # We will apply the function and reshape the result into a single-row
#     355     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     356     assert self.ndim == 2
# --> 358     result = func(self.values)
#     360     if self.values.ndim == 1:
#     361         res_values = result
#
# File ~\anaconda3\envs\pydate26\Lib\site-packages\pandas\core\frame.py:13563, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   13559         def blk_func(values, axis: Axis = 1):
#   13560             if isinstance(values, ExtensionArray):
#   13561                 if not is_1d_only_ea_dtype(values.dtype):
#   13562                     return values._reduce(name, axis=1, skipna=skipna, **kwds)
# > 13563                 return values._reduce(name, skipna=skipna, keepdims=True, **kwds)
#   13564             else:
#   13565                 return op(values, axis=axis, skipna=skipna, **kwds)
#
# File ~\anaconda3\envs\pydate26\Lib\site-packages\pandas\core\arrays\string_.py:968, in StringArray._reduce(self, name, skipna, keepdims, axis, **kwargs)
#     965         return self._from_sequence([result], dtype=self.dtype)
#     966     return result
# --> 968 raise TypeError(f"Cannot perform reduction '{name}' with string dtype")
#
# TypeError: Cannot perform reduction 'var' with string dtype

# %%
titanic_df.std()
# Out:
# passengerId    55.918708
# survived       55.013294
# pclass         54.392792
# age            40.246251
# sibsp          54.791741
# parch          54.864208
# fare           92.436707
# dtype: float64

# %%
titanic_df.skew()
# Out:
# passengerId    0.070288
# survived       2.828105
# pclass         2.826944
# age            1.674543
# sibsp          2.823355
# parch          2.823054
# fare           1.762901
# dtype: float64

# %%
titanic_df.kurt()
# Out:
# passengerId   -1.094301
# survived       7.998630
# pclass         7.993730
# age            2.742063
# sibsp          7.978057
# parch          7.976701
# fare           2.325692
# dtype: float64
